# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-edulira/atividade_p1_CD/blob/main/legenda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
  
# valores x
x = [1, 2, 3, 4, 5]
  
# valores y
y = [1, 4, 9, 200, 12]
  
plt.plot(x, y)
plt.legend(['linha simples'])
  
plt.show()
